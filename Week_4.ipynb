# %% [markdown]
# # Basic Statistical Testing

# %%
import numpy as np
import pandas as pd
import scipy as stats

# %%
df = pd.read_csv('datasets/Week4/grades.csv')

# %%
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
print("There are {} rows and {} comlumns ".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 comlumns

# %%
early_finish = df[pd.to_datetime(df['assignment1_submission']) <='2016']

# %%
early_finish
# Out:
#                                 student_id  assignment1_grade  \
# 0     B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1     98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4     5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5     D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8     C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
# ...                                    ...                ...
# 2308  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          71.481182
# 2309  6D2AB78F-44F4-2E8B-5C5E-B79119BC7EAC          82.640274
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 0     2015-11-02 06:55:34.282000000          83.030552
# 1     2015-11-29 14:57:44.429000000          86.290821
# ...

# %%
let_finish = df[~df.index.isin(early_finish.index)]

# %%
let_finish
# Out:
#                                 student_id  assignment1_grade  \
# 2     D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3     FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6     3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7     F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9     E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
# ...                                    ...                ...
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          97.215052
# 2306  DDE0526B-7DA4-80E8-C2A6-D097F3826029          47.696703
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          94.595758
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
#
#              assignment1_submission  assignment2_grade  \
# 2     2016-01-09 05:36:02.389000000          85.512541
# 3     2016-04-30 06:50:39.801000000          68.824532
# ...

# %%
print(early_finish['assignment1_grade'].mean())
print(let_finish['assignment1_grade'].mean())
# Out:
# 74.94728457024304
# 74.0450648477065

# %%
from scipy.stats import ttest_ind

ttest_ind(early_finish['assignment1_grade'], let_finish['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.3223540853721596, pvalue=0.18618101101713855)

# %%
ttest_ind(early_finish['assignment2_grade'], let_finish['assignment2_grade'])
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)

# %%
ttest_ind(early_finish['assignment3_grade'], let_finish['assignment3_grade'])
# Out:
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)

# %%
ttest_ind(early_finish['assignment4_grade'], let_finish['assignment4_grade'])
# Out:
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)

# %%
ttest_ind(early_finish['assignment5_grade'], let_finish['assignment5_grade'])
# Out:
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)

# %%
df1 = pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.128143  0.957294  0.366240  0.805678  0.198672  0.405864  0.571702
# 1  0.248157  0.395342  0.177164  0.728851  0.710830  0.430450  0.597388
# 2  0.956388  0.622306  0.007038  0.542025  0.394370  0.811024  0.617364
# 3  0.679288  0.777686  0.394925  0.388285  0.706030  0.039745  0.038522
# 4  0.343881  0.137875  0.535598  0.633771  0.302094  0.809028  0.515139
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.581095  0.235026  0.721289  ...  0.790962  0.995921  0.154681  0.841851
# 1  0.951315  0.027275  0.904904  ...  0.795094  0.183408  0.089495  0.172971
# 2  0.489642  0.666639  0.319010  ...  0.806904  0.943704  0.962847  0.870171
# 3  0.544467  0.824305  0.215407  ...  0.906029  0.873820  0.482872  0.197603
# 4  0.143308  0.080611  0.751739  ...  0.887398  0.285357  0.686192  0.338942
#
#          94        95        96        97        98        99
# ...

# %%
df2 = pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
df2
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.260007  0.116320  0.417676  0.820452  0.627703  0.378914  0.071342
# 1   0.963334  0.022205  0.826630  0.097399  0.456893  0.082172  0.131677
# 2   0.782032  0.595996  0.016497  0.060559  0.874829  0.282227  0.282369
# 3   0.306170  0.593339  0.655305  0.330671  0.228134  0.166175  0.442187
# 4   0.768773  0.093560  0.224832  0.252177  0.046078  0.250809  0.723687
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.736019  0.229362  0.482233  0.509612  0.410983  0.477626  0.517283
# 96  0.512972  0.195647  0.249450  0.016248  0.202284  0.373213  0.978962
# 97  0.400146  0.187378  0.697551  0.198756  0.636921  0.693372  0.078575
# 98  0.634579  0.336682  0.608841  0.407866  0.963313  0.885923  0.337136
# 99  0.577637  0.000727  0.103144  0.720865  0.222558  0.233028  0.672507
#
#           7         8         9   ...        90        91        92        93  \
# ...

# %%
pd.DataFrame([np.random.random(100) ])
# Out:
#          0        1         2         3         4         5         6   \
# 0  0.205898  0.74038  0.043598  0.398912  0.582665  0.315205  0.959272
#
#          7         8         9   ...        90        91       92       93  \
# 0  0.827355  0.661477  0.798145  ...  0.274212  0.326012  0.65824  0.05329
#
#          94        95        96        97        98        99
# 0  0.027345  0.411401  0.164244  0.719522  0.214514  0.938412
#
# [1 rows x 100 columns]

# %%
pd.DataFrame([np.random.random(100) for x in range(100) ])
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.724942  0.409936  0.573335  0.407051  0.694686  0.615594  0.307633
# 1   0.243442  0.654437  0.887661  0.645078  0.260713  0.111363  0.625860
# 2   0.480277  0.600281  0.859410  0.577734  0.298548  0.794893  0.074086
# 3   0.565870  0.589148  0.397432  0.713822  0.477252  0.764009  0.963276
# 4   0.103635  0.422915  0.563317  0.681475  0.133775  0.324848  0.772982
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.055416  0.992937  0.690547  0.222745  0.996930  0.870451  0.499166
# 96  0.847646  0.902090  0.101218  0.739120  0.608615  0.250980  0.828609
# 97  0.323593  0.171432  0.616248  0.142938  0.043284  0.700374  0.660778
# 98  0.575997  0.400737  0.767958  0.005280  0.085693  0.760481  0.673707
# 99  0.370282  0.102432  0.557223  0.464409  0.833103  0.626839  0.759674
#
#           7         8         9   ...        90        91        92        93  \
# ...

# %%
def test_columns(alpha=0.1):
    num_diff  = 0
    
    for col in df1.columns:
        teststat,pval = ttest_ind(df1[col], df2[col])
        
        if (pval<= alpha):
            print('col {} is statistically significate diff at alpha={}, pval={}'.format(col,alpha,pval))
            num_diff = num_diff+1
    print('Total number different was {} which is {} %'.format(num_diff,float(num_diff)/len(df1.columns)*100))

# %%
test_columns()
# Out:
# col 5 is statistically significate diff at alpha=0.1, pval=0.014609777613612391
# col 9 is statistically significate diff at alpha=0.1, pval=0.057335611791429715
# col 14 is statistically significate diff at alpha=0.1, pval=0.07345698783684192
# col 20 is statistically significate diff at alpha=0.1, pval=0.05070875750199553
# col 26 is statistically significate diff at alpha=0.1, pval=0.00506333528063023
# col 28 is statistically significate diff at alpha=0.1, pval=0.04168803557838423
# col 32 is statistically significate diff at alpha=0.1, pval=0.07207829033178094
# col 35 is statistically significate diff at alpha=0.1, pval=0.005379054473026811
# col 38 is statistically significate diff at alpha=0.1, pval=0.09015984171225933
# col 42 is statistically significate diff at alpha=0.1, pval=0.006357908368467538
# col 57 is statistically significate diff at alpha=0.1, pval=0.0862507775889975
# col 60 is statistically significate diff at alpha=0.1, pval=0.011388077552025488
# ...

# %%
df2 = pd.DataFrame([np.random.chisquare(df=1, size=100) for x in range(1000)])

# %%
test_columns()
# Out:
# col 0 is statistically significate diff at alpha=0.1, pval=0.0002186682523515916
# col 1 is statistically significate diff at alpha=0.1, pval=0.00020287845369454225
# col 2 is statistically significate diff at alpha=0.1, pval=0.0002671998775180356
# col 3 is statistically significate diff at alpha=0.1, pval=0.0009934183692106456
# col 4 is statistically significate diff at alpha=0.1, pval=0.0007181392147047943
# col 5 is statistically significate diff at alpha=0.1, pval=0.0014963668594252244
# col 6 is statistically significate diff at alpha=0.1, pval=0.00038281004249467957
# col 7 is statistically significate diff at alpha=0.1, pval=0.00187900953500446
# col 8 is statistically significate diff at alpha=0.1, pval=0.00027482432737739517
# col 9 is statistically significate diff at alpha=0.1, pval=0.00040082634372960653
# col 10 is statistically significate diff at alpha=0.1, pval=0.0003641658677148797
# col 11 is statistically significate diff at alpha=0.1, pval=0.0007007644625221348
# ...

# %% [markdown]
# # Other Forms of Structured Data
